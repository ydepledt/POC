# %%
from transformers import AutoProcessor, MusicgenForConditionalGeneration

# %%
processor = AutoProcessor.from_pretrained("facebook/musicgen-small")
model = MusicgenForConditionalGeneration.from_pretrained("facebook/musicgen-small")
# Out:
# preprocessor_config.json:   0%|          | 0.00/275 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.37k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/7.87k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.36G [00:00<?, ?B/s]
# /home/ydepledt/py_env/hugging_face/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:134: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# /home/ydepledt/py_env/hugging_face/lib/python3.10/site-packages/transformers/models/encodec/modeling_encodec.py:120: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer("padding_total", torch.tensor(kernel_size - stride, dtype=torch.int64), persistent=False)
# generation_config.json:   0%|          | 0.00/224 [00:00<?, ?B/s]

# %%
inputs = processor(
    text=["a night lofi style music with sadness vibes"],
    padding=True,
    return_tensors="pt",
    device="cuda",
)

# %%
audio_values = model.generate(**inputs, max_new_tokens=256)
# Out:
# `torch.nn.functional.scaled_dot_product_attention` does not support having an empty attention mask. Falling back to the manual attention implementation. This warning can be removed using the argument `attn_implementation="eager"` when loading the model.Note that this probably happens because `guidance_scale>1` or because you used `get_unconditional_inputs`. See https://github.com/huggingface/transformers/issues/31189 for more information.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 audio_values = model.generate(**inputs, max_new_tokens=256)
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/transformers/models/musicgen/modeling_musicgen.py:2668, in MusicgenForConditionalGeneration.generate(self, inputs, generation_config, logits_processor, stopping_criteria, synced_gpus, streamer, **kwargs)
#    2660     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2661         input_ids=input_ids,
#    2662         expand_size=generation_config.num_return_sequences,
#    2663         is_encoder_decoder=self.config.is_encoder_decoder,
#    2664         **model_kwargs,
#    2665     )
#    2667     # 12. run sample
# -> 2668     outputs = self._sample(
#    2669         input_ids,
#    2670         logits_processor=logits_processor,
#    2671         logits_warper=prepared_logits_warper,
#    2672         stopping_criteria=stopping_criteria,
#    2673         generation_config=generation_config,
#    2674         synced_gpus=synced_gpus,
#    2675         streamer=streamer,
#    2676         **model_kwargs,
#    2677     )
#    2679 else:
#    2680     raise ValueError(
#    2681         "Got incompatible mode for generation, should be one of greedy or sampling. "
#    2682         "Ensure that beam search is de-activated by setting `num_beams=1` and `num_beam_groups=1`."
#    2683     )
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/transformers/generation/utils.py:2981, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, logits_warper, **model_kwargs)
#    2978 model_inputs.update({"output_hidden_states": output_hidden_states} if output_hidden_states else {})
#    2980 # forward pass to get next token
# -> 2981 outputs = self(**model_inputs, return_dict=True)
#    2983 if synced_gpus and this_peer_finished:
#    2984     continue  # don't waste resources running the code we don't need
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/transformers/models/musicgen/modeling_musicgen.py:2140, in MusicgenForConditionalGeneration.forward(self, input_ids, attention_mask, input_values, padding_mask, decoder_input_ids, decoder_attention_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, **kwargs)
#    2137     decoder_input_ids = audio_codes[0, ...].reshape(bsz * self.decoder.num_codebooks, seq_len)
#    2139 # Decode
# -> 2140 decoder_outputs = self.decoder(
#    2141     input_ids=decoder_input_ids,
#    2142     attention_mask=decoder_attention_mask,
#    2143     encoder_hidden_states=encoder_hidden_states,
#    2144     encoder_attention_mask=attention_mask,
#    2145     inputs_embeds=decoder_inputs_embeds,
#    2146     output_attentions=output_attentions,
#    2147     output_hidden_states=output_hidden_states,
#    2148     use_cache=use_cache,
#    2149     past_key_values=past_key_values,
#    2150     return_dict=return_dict,
#    2151     labels=labels,
#    2152     **kwargs_decoder,
#    2153 )
#    2155 if not return_dict:
#    2156     return decoder_outputs + encoder_outputs
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/transformers/models/musicgen/modeling_musicgen.py:1272, in MusicgenForCausalLM.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1269 if (labels is not None) and (input_ids is None and inputs_embeds is None):
#    1270     input_ids = shift_tokens_right(labels, self.config.pad_token_id, self.config.bos_token_id)
# -> 1272 outputs = self.model(
#    1273     input_ids,
#    1274     attention_mask=attention_mask,
#    1275     encoder_hidden_states=encoder_hidden_states,
#    1276     encoder_attention_mask=encoder_attention_mask,
#    1277     head_mask=head_mask,
#    1278     cross_attn_head_mask=cross_attn_head_mask,
#    1279     past_key_values=past_key_values,
#    1280     inputs_embeds=inputs_embeds,
#    1281     use_cache=use_cache,
#    1282     output_attentions=output_attentions,
#    1283     output_hidden_states=output_hidden_states,
#    1284     return_dict=return_dict,
#    1285 )
#    1287 hidden_states = outputs[0]
#    1289 lm_logits = torch.stack([head(hidden_states) for head in self.lm_heads], dim=1)
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/transformers/models/musicgen/modeling_musicgen.py:1178, in MusicgenModel.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1175 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1177 # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1178 decoder_outputs = self.decoder(
#    1179     input_ids=input_ids,
#    1180     attention_mask=attention_mask,
#    1181     encoder_attention_mask=encoder_attention_mask,
#    1182     encoder_hidden_states=encoder_hidden_states,
#    1183     head_mask=head_mask,
#    1184     cross_attn_head_mask=cross_attn_head_mask,
#    1185     past_key_values=past_key_values,
#    1186     inputs_embeds=inputs_embeds,
#    1187     use_cache=use_cache,
#    1188     output_attentions=output_attentions,
#    1189     output_hidden_states=output_hidden_states,
#    1190     return_dict=return_dict,
#    1191 )
#    1193 if not return_dict:
#    1194     return decoder_outputs
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/transformers/models/musicgen/modeling_musicgen.py:1088, in MusicgenDecoder.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1075     layer_outputs = self._gradient_checkpointing_func(
#    1076         decoder_layer.forward,
#    1077         hidden_states,
#    (...)
#    1085         use_cache,
#    1086     )
#    1087 else:
# -> 1088     layer_outputs = decoder_layer(
#    1089         hidden_states,
#    1090         attention_mask=attention_mask,
#    1091         encoder_hidden_states=encoder_hidden_states,
#    1092         encoder_attention_mask=encoder_attention_mask,
#    1093         layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#    1094         cross_attn_layer_head_mask=(
#    1095             cross_attn_head_mask[idx] if cross_attn_head_mask is not None else None
#    1096         ),
#    1097         past_key_value=past_key_value,
#    1098         output_attentions=output_attentions,
#    1099         use_cache=use_cache,
#    1100     )
#    1101 hidden_states = layer_outputs[0]
#    1103 if use_cache:
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/transformers/models/musicgen/modeling_musicgen.py:680, in MusicgenDecoderLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, output_attentions, use_cache)
#     678 hidden_states = self.activation_fn(self.fc1(hidden_states))
#     679 hidden_states = nn.functional.dropout(hidden_states, p=self.activation_dropout, training=self.training)
# --> 680 hidden_states = self.fc2(hidden_states)
#     681 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     682 hidden_states = residual + hidden_states
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/py_env/hugging_face/lib/python3.10/site-packages/torch/nn/modules/linear.py:117, in Linear.forward(self, input)
#     116 def forward(self, input: Tensor) -> Tensor:
# --> 117     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
